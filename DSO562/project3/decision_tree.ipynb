# %%
import pandas as pd
import numpy as np
import os,time
from sklearn import tree
from sklearn.model_selection import train_test_split
import graphviz

# %%
path = os.getcwd()+'/'

# %%
data = pd.read_csv(path+'train_m.csv')

# %%
data_2 = pd.read_csv(path+'train_40.csv')

# %%
ood = pd.read_csv(path+'out_of_date_m.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  merchantnum_amount_sum_3  merchantnum_amount_week_diff_sum_3  \
# 0           0                      3.62                         -364.485464
# 1           1                     31.42                         -336.685464
# 2           2                    178.49                         -189.615464
# 3           3                      7.24                         -728.970927
# 4           4                     10.86                        -1093.456391
#
#    cardnum_amount_sum_3  cardnum_amount_week_diff_sum_3  newmerch_30  \
# 0                  3.62                     -364.485464            1
# 1                 31.42                     -336.685464            1
# 2                178.49                     -189.615464            1
# 3                  3.62                     -364.485464            0
# 4                  7.24                     -728.970927            1
#
#    newmerch_15  cardnum_merchantnum_30  cardnum_merchantnum_15  \
# ...

# %%
x = data.iloc[:,1:-1]
y = data.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
clf = tree.DecisionTreeRegressor(max_depth=3)
clf = clf.fit(x_train, y_train)

# %%
test_pred = clf.predict(x_test)

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=x_train.columns,  
                         class_names=list(y_train.unique()),  
                         filled=True, rounded=True,  
                         special_characters=True)
graph = graphviz.Source(dot_data)

# %%
graph

# %%
x_2 = data_2.iloc[:,1:-1]
y_2 = data_2.iloc[:,-1]
x_train_2, x_test_2, y_train_2, y_test_2 = train_test_split(x_2, y_2, test_size=0.2, random_state=0)

# %%
clf_2 = tree.DecisionTreeRegressor(max_depth=3)
clf_2 = clf.fit(x_train_2, y_train_2)
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=x_train_2.columns,  
                         class_names=list(y_train_2.unique()),  
                         filled=True, rounded=True,  
                         special_characters=True)
graph = graphviz.Source(dot_data)

# %%
graph
